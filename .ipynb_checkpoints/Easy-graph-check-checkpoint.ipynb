# %%
# %pylab inline 
import numpy as np
import pandas as pd
import os, sys
import random
import networkx as nx
import matplotlib.pyplot as plt
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # Creation

# %%
class simplex_vertex:
    '''
    Vertex class for simplicial activity driven model
    '''
    import random
    def __init__(self,vertex_id,activity):
        self.act = activity;
        self.name = vertex_id;
        self.memory = [];
    
    def update_history(self,newcollab):
        self.memory.append(newcollab);
                
    def repeat_collaboration(self):
        s = random.choice(self.memory);
        self.memory.append(s)
        return s;

    def new_collab(self,nodes,size):
        el = random.sample(nodes,size);
        el.append(self.name);
        self.memory.append(el);
        return el;

def add_clique(e,tgraph):
    g = nx.complete_graph(len(e));
    rl = dict(zip(range(len(e)), e));
    g = nx.relabel_nodes(g,rl)
    tgraph.add_edges_from(g.edges());
    return tgraph;
        
def memory_instant_graph(vertex_dict):
    tgraph = nx.Graph()
    tgraph.add_nodes_from(vertex_dict.keys());
    new_history = []
    for n in vertex_dict:
        if np.random.rand()<=vertex_dict[n].act:
            if np.random.rand() <= (len(vertex_dict[n].memory) / float(1+len(vertex_dict[n].memory))):
                e = vertex_dict[n].repeat_collaboration();
                tgraph = add_clique(e,tgraph);                
            else:
                nodes = vertex_dict.keys();
                nodes.remove(n)
                e = vertex_dict[n].new_collab(nodes,np.random.randint(10));
            new_history.append(e);
            tgraph = add_clique(e,tgraph);
    return tgraph, new_history;

def memoryless_instant_graph(vertex_dict,k):
    tgraph = nx.Graph()
    tgraph.add_nodes_from(vertex_dict.keys());
    new_history = []
    for n in vertex_dict:
        if np.random.rand()<=vertex_dict[n].act:
            nodes = vertex_dict.keys();
            nodes.remove(n)
            e = vertex_dict[n].new_collab(nodes,k);
            new_history.append(e);
            tgraph = add_clique(e,tgraph);
    return tgraph, new_history;

def threshold_ratio(k, a1,a2):
    return 2.0 / (k*(k-1) * a1 + (k-1)*np.sqrt(k*k*a1*a1 + 4*(a2-a1*a1)));

def temporal_graph_creation(N,T,k,act,seed=1,verbose=False):
    tgraph = {}
    vertex_dict = {}
    for n in range(N):
        vertex_dict[n] = simplex_vertex(n,act[n])
    for t in range(T):
        if verbose == True and T%100==0:
            print T;
        tg, fh = memoryless_instant_graph(vertex_dict,k);
        tgraph[t] = tg
    return tgraph;

def temporal_graph_export(tgraph,filename):
    f = open(filename,'w');
    for t in tgraph:
        for edge in tgraph[t].edges():
            f.write('\t'.join(map(str,[t,edge[0],edge[1]]))+'\n')
    return;

# %%
N = 1000
# produce activities 
from scipy.stats import norm,pareto
b = 2.1
dist = pareto(b).rvs(100000)
dist = np.random.choice(dist,N)
act = dict(zip(range(N),dist/np.max(dist)))
plt.hist(act.values())
mu, v  = np.mean(act.values()), np.var(act.values())
print mu, v
# Out:
# 0.117482210326 0.00803434077894

# %%
# predict thresholds
ks = range(2,6)
thrs = {}
for k in ks:
    thrs[k] = threshold_ratio(k,mu,v)
    print k, thrs[k]

max_lambda = 0.1;
[max_lambda / thrs[k] for k in thrs]
# Out:
# 2 4.82819601636
# 3 1.49146009738
# 4 0.72888943393
# 5 0.432958686878
# [0.020711669464352919,
#  0.067048391154412829,
#  0.13719501936100481,
#  0.2309689192775003]

# %%
import time
epi  = {}
T  = 2000;
N = 300;
recovery_factor = 1.02
for k in ks:
    now = time.time()
    epi[k] = temporal_graph_creation(N,T,k,act,seed=10)
    print   'lambda, mu', max_lambda,max_lambda/thrs[k], 'time completed', k, time.time() - now
# Out:
# lambda, mu 0.1 0.0207116694644 time completed 2 13.6939911842
# lambda, mu 0.1 0.0670483911544 time completed 3 15.991163969
# lambda, mu 0.1 0.137195019361 time completed 4 15.1024060249
# lambda, mu 0.1 0.230968919278 time completed 5 21.1096849442

# %%
# %%sh
# mkdir ../data/test/

# %%
for k in epi:
    temporal_graph_export(epi[k], '../data/test/test-'+str(k)+'.pck')

# %% [markdown]
# # Analysis

# %%
output = np.genfromtxt('../data/test/avg(I_t)-test-3.pck,N=100,dt=1,T=2000,beta=0.1,mu=0.1070483911544,Q=100,res=1.txt')
plt.plot(output)

# %%
avg(I_t)-test-3.pck,N=100,dt=1,T=2000,beta=0.1,mu=0.1,Q=100,res=1.txt
avg(I_t)-test-3.pck,N=100,dt=1,T=2000,beta=0.1,mu=0.2,Q=100,res=1.txt
avg(I_t)-test-3.pck,N=100,dt=1,T=2000,beta=0.1,mu=0.3,Q=100,res=1.txt
avg(I_t)-test-3.pck,N=100,dt=1,T=2000,beta=0.1,mu=0.4,Q=100,res=1.txt
avg(I_t)-test-3.pck,N=100,dt=1,T=2000,beta=0.1,mu=0.5,Q=100,res=1.txt
avg(I_t)-test-3.pck,N=100,dt=1,T=2000,beta=0.1,mu=0.6,Q=100,res=1.txt
avg(I_t)-test-3.pck,N=100,dt=1,T=2000,beta=0.1,mu=0.7,Q=100,res=1.txt
avg(I_t)-test-3.pck,N=100,dt=1,T=2000,beta=0.1,mu=0.8,Q=100,res=1.txt
avg(I_t)-test-3.pck,N=100,dt=1,T=2000,beta=0.1,mu=0.9,Q=100,res=1.txt
avg(I_t)-test-3.pck,N=100,dt=1,T=2000,beta=0.1,mu=1.00,Q=100,res=1.txt
# Out:
# 0

# %%
0.1/1.49
# Out:
# 0.06711409395973154

# %%
# %%sh
# ls ../data/test/3/avg*
# Out:
# ../data/test/3/avg(I_t)-test-3.pck,N=100,dt=1,T=2000,beta=0.1,mu=0.012,Q=500,res=1.txt
# ../data/test/3/avg(I_t)-test-3.pck,N=100,dt=1,T=2000,beta=0.1,mu=0.014,Q=500,res=1.txt
# ../data/test/3/avg(I_t)-test-3.pck,N=100,dt=1,T=2000,beta=0.1,mu=0.016,Q=500,res=1.txt
# ../data/test/3/avg(I_t)-test-3.pck,N=100,dt=1,T=2000,beta=0.1,mu=0.018,Q=500,res=1.txt
# ../data/test/3/avg(I_t)-test-3.pck,N=100,dt=1,T=2000,beta=0.1,mu=0.020,Q=500,res=1.txt
# ../data/test/3/avg(I_t)-test-3.pck,N=100,dt=1,T=2000,beta=0.1,mu=0.022,Q=500,res=1.txt
# ../data/test/3/avg(I_t)-test-3.pck,N=100,dt=1,T=2000,beta=0.1,mu=0.024,Q=500,res=1.txt
# ../data/test/3/avg(I_t)-test-3.pck,N=100,dt=1,T=2000,beta=0.1,mu=0.026,Q=500,res=1.txt
# ../data/test/3/avg(I_t)-test-3.pck,N=100,dt=1,T=2000,beta=0.1,mu=0.028,Q=500,res=1.txt
# ../data/test/3/avg(I_t)-test-3.pck,N=100,dt=1,T=2000,beta=0.1,mu=0.030,Q=500,res=1.txt
# ../data/test/3/avg(I_t)-test-3.pck,N=100,dt=1,T=2000,beta=0.1,mu=0.032,Q=500,res=1.txt
# ../data/test/3/avg(I_t)-test-3.pck,N=100,dt=1,T=2000,beta=0.1,mu=0.034,Q=500,res=1.txt
# ../data/test/3/avg(I_t)-test-3.pck,N=100,dt=1,T=2000,beta=0.1,mu=0.036,Q=500,res=1.txt
# ../data/test/3/avg(I_t)-test-3.pck,N=100,dt=1,T=2000,beta=0.1,mu=0.038,Q=500,res=1.txt
# ../data/test/3/avg(I_t)-test-3.pck,N=100,dt=1,T=2000,beta=0.1,mu=0.040,Q=500,res=1.txt
# ../data/test/3/avg(I_t)-test-3.pck,N=100,dt=1,T=2000,beta=0.1,mu=0.042,Q=500,res=1.txt
# ../data/test/3/avg(I_t)-test-3.pck,N=100,dt=1,T=2000,beta=0.1,mu=0.044,Q=500,res=1.txt
# ../data/test/3/avg(I_t)-test-3.pck,N=100,dt=1,T=2000,beta=0.1,mu=0.046,Q=500,res=1.txt
# ../data/test/3/avg(I_t)-test-3.pck,N=100,dt=1,T=2000,beta=0.1,mu=0.048,Q=500,res=1.txt
# ../data/test/3/avg(I_t)-test-3.pck,N=100,dt=1,T=2000,beta=0.1,mu=0.050,Q=500,res=1.txt
# ../data/test/3/avg(I_t)-test-3.pck,N=100,dt=1,T=2000,beta=0.1,mu=0.052,Q=500,res=1.txt
# ../data/test/3/avg(I_t)-test-3.pck,N=100,dt=1,T=2000,beta=0.1,mu=0.054,Q=500,res=1.txt
# ../data/test/3/avg(I_t)-test-3.pck,N=100,dt=1,T=2000,beta=0.1,mu=0.056,Q=500,res=1.txt
# ../data/test/3/avg(I_t)-test-3.pck,N=100,dt=1,T=2000,beta=0.1,mu=0.058,Q=500,res=1.txt
# ../data/test/3/avg(I_t)-test-3.pck,N=100,dt=1,T=2000,beta=0.1,mu=0.060,Q=500,res=1.txt
# ../data/test/3/avg(I_t)-test-3.pck,N=100,dt=1,T=2000,beta=0.1,mu=0.062,Q=500,res=1.txt
# ../data/test/3/avg(I_t)-test-3.pck,N=100,dt=1,T=2000,beta=0.1,mu=0.064,Q=500,res=1.txt
# ../data/test/3/avg(I_t)-test-3.pck,N=100,dt=1,T=2000,beta=0.1,mu=0.066,Q=500,res=1.txt
# ../data/test/3/avg(I_t)-test-3.pck,N=100,dt=1,T=2000,beta=0.1,mu=0.068,Q=500,res=1.txt
# ../data/test/3/avg(I_t)-test-3.pck,N=100,dt=1,T=2000,beta=0.1,mu=0.070,Q=500,res=1.txt
# ../data/test/3/avg(I_t)-test-3.pck,N=100,dt=1,T=2000,beta=0.1,mu=0.072,Q=500,res=1.txt
# ../data/test/3/avg(I_t)-test-3.pck,N=100,dt=1,T=2000,beta=0.1,mu=0.074,Q=500,res=1.txt
# ../data/test/3/avg(I_t)-test-3.pck,N=100,dt=1,T=2000,beta=0.1,mu=0.076,Q=500,res=1.txt
# ../data/test/3/avg(I_t)-test-3.pck,N=100,dt=1,T=2000,beta=0.1,mu=0.078,Q=500,res=1.txt
# ../data/test/3/avg(I_t)-test-3.pck,N=100,dt=1,T=2000,beta=0.1,mu=0.080,Q=500,res=1.txt
# ../data/test/3/avg(I_t)-test-3.pck,N=100,dt=1,T=2000,beta=0.1,mu=0.082,Q=500,res=1.txt
# ../data/test/3/avg(I_t)-test-3.pck,N=100,dt=1,T=2000,beta=0.1,mu=0.084,Q=500,res=1.txt
# ../data/test/3/avg(I_t)-test-3.pck,N=100,dt=1,T=2000,beta=0.1,mu=0.086,Q=500,res=1.txt
# ../data/test/3/avg(I_t)-test-3.pck,N=100,dt=1,T=2000,beta=0.1,mu=0.088,Q=500,res=1.txt
# ../data/test/3/avg(I_t)-test-3.pck,N=100,dt=1,T=2000,beta=0.1,mu=0.090,Q=500,res=1.txt

# %%
x = map(lambda x: format(x,'.3f'), np.linspace(0.012,0.09,40))
print x
# Out:
# ['0.012', '0.014', '0.016', '0.018', '0.020', '0.022', '0.024', '0.026', '0.028', '0.030', '0.032', '0.034', '0.036', '0.038', '0.040', '0.042', '0.044', '0.046', '0.048', '0.050', '0.052', '0.054', '0.056', '0.058', '0.060', '0.062', '0.064', '0.066', '0.068', '0.070', '0.072', '0.074', '0.076', '0.078', '0.080', '0.082', '0.084', '0.086', '0.088', '0.090']

# %%
trans = []
for i in x:
    print i
    st = '../data/test/3/avg(I_t)-test-3.pck,N=100,dt=1,T=2000,beta=0.1,mu='+str(i)+',Q=500,res=1.txt'
    print st
    d = np.genfromtxt(st);
    plt.plot(d,label=i)
    trans.append(np.mean(d))
    plt.legend(loc=0)
plt.show()
# Out:
# 0.012
# ../data/test/3/avg(I_t)-test-3.pck,N=100,dt=1,T=2000,beta=0.1,mu=0.012,Q=500,res=1.txt
# 0.014
# ../data/test/3/avg(I_t)-test-3.pck,N=100,dt=1,T=2000,beta=0.1,mu=0.014,Q=500,res=1.txt
# 0.016
# ../data/test/3/avg(I_t)-test-3.pck,N=100,dt=1,T=2000,beta=0.1,mu=0.016,Q=500,res=1.txt
# 0.018
# ../data/test/3/avg(I_t)-test-3.pck,N=100,dt=1,T=2000,beta=0.1,mu=0.018,Q=500,res=1.txt
# 0.020
# ../data/test/3/avg(I_t)-test-3.pck,N=100,dt=1,T=2000,beta=0.1,mu=0.020,Q=500,res=1.txt
# 0.022
# ../data/test/3/avg(I_t)-test-3.pck,N=100,dt=1,T=2000,beta=0.1,mu=0.022,Q=500,res=1.txt
# 0.024
# ../data/test/3/avg(I_t)-test-3.pck,N=100,dt=1,T=2000,beta=0.1,mu=0.024,Q=500,res=1.txt
# 0.026
# ../data/test/3/avg(I_t)-test-3.pck,N=100,dt=1,T=2000,beta=0.1,mu=0.026,Q=500,res=1.txt
# 0.028
# ../data/test/3/avg(I_t)-test-3.pck,N=100,dt=1,T=2000,beta=0.1,mu=0.028,Q=500,res=1.txt
# 0.030
# ../data/test/3/avg(I_t)-test-3.pck,N=100,dt=1,T=2000,beta=0.1,mu=0.030,Q=500,res=1.txt
# 0.032
# ../data/test/3/avg(I_t)-test-3.pck,N=100,dt=1,T=2000,beta=0.1,mu=0.032,Q=500,res=1.txt
# 0.034
# ../data/test/3/avg(I_t)-test-3.pck,N=100,dt=1,T=2000,beta=0.1,mu=0.034,Q=500,res=1.txt
# 0.036
# ../data/test/3/avg(I_t)-test-3.pck,N=100,dt=1,T=2000,beta=0.1,mu=0.036,Q=500,res=1.txt
# 0.038
# ../data/test/3/avg(I_t)-test-3.pck,N=100,dt=1,T=2000,beta=0.1,mu=0.038,Q=500,res=1.txt
# 0.040
# ../data/test/3/avg(I_t)-test-3.pck,N=100,dt=1,T=2000,beta=0.1,mu=0.040,Q=500,res=1.txt
# 0.042
# ../data/test/3/avg(I_t)-test-3.pck,N=100,dt=1,T=2000,beta=0.1,mu=0.042,Q=500,res=1.txt
# 0.044
# ../data/test/3/avg(I_t)-test-3.pck,N=100,dt=1,T=2000,beta=0.1,mu=0.044,Q=500,res=1.txt
# 0.046
# ../data/test/3/avg(I_t)-test-3.pck,N=100,dt=1,T=2000,beta=0.1,mu=0.046,Q=500,res=1.txt
# 0.048
# ../data/test/3/avg(I_t)-test-3.pck,N=100,dt=1,T=2000,beta=0.1,mu=0.048,Q=500,res=1.txt
# 0.050
# ../data/test/3/avg(I_t)-test-3.pck,N=100,dt=1,T=2000,beta=0.1,mu=0.050,Q=500,res=1.txt
# 0.052
# ../data/test/3/avg(I_t)-test-3.pck,N=100,dt=1,T=2000,beta=0.1,mu=0.052,Q=500,res=1.txt
# 0.054
# ../data/test/3/avg(I_t)-test-3.pck,N=100,dt=1,T=2000,beta=0.1,mu=0.054,Q=500,res=1.txt
# 0.056
# ../data/test/3/avg(I_t)-test-3.pck,N=100,dt=1,T=2000,beta=0.1,mu=0.056,Q=500,res=1.txt
# 0.058
# ../data/test/3/avg(I_t)-test-3.pck,N=100,dt=1,T=2000,beta=0.1,mu=0.058,Q=500,res=1.txt
# 0.060
# ../data/test/3/avg(I_t)-test-3.pck,N=100,dt=1,T=2000,beta=0.1,mu=0.060,Q=500,res=1.txt
# 0.062
# ../data/test/3/avg(I_t)-test-3.pck,N=100,dt=1,T=2000,beta=0.1,mu=0.062,Q=500,res=1.txt
# 0.064
# ../data/test/3/avg(I_t)-test-3.pck,N=100,dt=1,T=2000,beta=0.1,mu=0.064,Q=500,res=1.txt
# 0.066
# ../data/test/3/avg(I_t)-test-3.pck,N=100,dt=1,T=2000,beta=0.1,mu=0.066,Q=500,res=1.txt
# 0.068
# ../data/test/3/avg(I_t)-test-3.pck,N=100,dt=1,T=2000,beta=0.1,mu=0.068,Q=500,res=1.txt
# 0.070
# ../data/test/3/avg(I_t)-test-3.pck,N=100,dt=1,T=2000,beta=0.1,mu=0.070,Q=500,res=1.txt
# 0.072
# ../data/test/3/avg(I_t)-test-3.pck,N=100,dt=1,T=2000,beta=0.1,mu=0.072,Q=500,res=1.txt
# 0.074
# ../data/test/3/avg(I_t)-test-3.pck,N=100,dt=1,T=2000,beta=0.1,mu=0.074,Q=500,res=1.txt
# 0.076
# ../data/test/3/avg(I_t)-test-3.pck,N=100,dt=1,T=2000,beta=0.1,mu=0.076,Q=500,res=1.txt
# 0.078
# ../data/test/3/avg(I_t)-test-3.pck,N=100,dt=1,T=2000,beta=0.1,mu=0.078,Q=500,res=1.txt
# 0.080
# ../data/test/3/avg(I_t)-test-3.pck,N=100,dt=1,T=2000,beta=0.1,mu=0.080,Q=500,res=1.txt
# 0.082
# ../data/test/3/avg(I_t)-test-3.pck,N=100,dt=1,T=2000,beta=0.1,mu=0.082,Q=500,res=1.txt
# 0.084
# ../data/test/3/avg(I_t)-test-3.pck,N=100,dt=1,T=2000,beta=0.1,mu=0.084,Q=500,res=1.txt
# 0.086
# ../data/test/3/avg(I_t)-test-3.pck,N=100,dt=1,T=2000,beta=0.1,mu=0.086,Q=500,res=1.txt
# 0.088
# ../data/test/3/avg(I_t)-test-3.pck,N=100,dt=1,T=2000,beta=0.1,mu=0.088,Q=500,res=1.txt
# 0.090
# ../data/test/3/avg(I_t)-test-3.pck,N=100,dt=1,T=2000,beta=0.1,mu=0.090,Q=500,res=1.txt

# %%
xx = np.array(map(float,x))

# %%
plt.plot(0.1/xx, trans)
threshold_ratio(3,np.mean(act.values()), np.var(act.values()))
plt.vlines(threshold_ratio(3,np.mean(act.values()), np.var(act.values())),0,N)

# %%
# Out:
# 1.4914600973750352
